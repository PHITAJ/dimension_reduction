# %% [markdown]
# # LLE

# %%
from sklearn.datasets import fetch_openml, make_blobs, make_swiss_roll, make_circles
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import LocallyLinearEmbedding
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from scipy import ndimage

# %% [markdown]
#    1. Générer un swiss roll de 2000 points et l'afficher en couleur, en 3D et en 2D (selon les axes permettant de voir la spirale).

# %%
df = make_swiss_roll(2000)

# %%
plt.scatter(df[0][:,0], df[0][:,2], c=df[1])

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.scatter(df[0][:,0], df[0][:,1], df[0][:,2], c=df[1])
plt.show()

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    2. Transformer le swiss roll en 2 dimensions grâce à LLE, en testant différents nombres de voisins. Combien faut-il prendre de voisins pour un résultat optimal ?
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    3. Augmenter progressivement le niveau de bruit de 0 à 1. Afficher côte à côte le swiss roll en spirale et le résultat de LLE. Interpréter le résultat et le relier avec le comportement obtenu pour un grand nombre de voisins à la question précédente.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    4. Transformer les données avec Modified LLE. Expliquer la différence obtenue.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    5. Faire varier le paramètre reg de LLE. Expliquer son rôle.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    6. Transformer le swiss roll avec Hessian LLE et LTSA
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    7. Transformer avec LLE les données suivantes, pour différents nombres de voisins. Expliquer la réduction à 3 points.
# </h3>

# %%
X_blob, y_blob = make_blobs(n_samples=1500, random_state=170)

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    8. Transformer avec LLE les fonnées suivantes, et comparer le résultat avec la transformation par PCA.
# </h3>

# %%
X_circle , y_circle = make_circles(n_samples=1000, factor=0.3, noise=0.05, random_state=0)

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    9. Transformer avec LLE le jeu de données digits en optimisant les paramètres.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    10. Chosir un chiffre (par exemple 4) et  extraire le jeu de données de MNIST correspondant à ce chiffre. En transformer 50%  avec LLE. Afficher dans l'espace transformé quelques images du jeu de données.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    11. Ajouter les 50% restant sur la même figure dans une autre couleur.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    12. Choisir un élement du jeu de donnée, le faire tourner degré par degré (entre -45 et +45) et calculer le plongement pour chaque rotation. Afficher le chemin parcouru dans l'espace en 2D avec une ligne entre les différents points
# </h3>

# %% [markdown]
# ## Optionnel

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    13. Pourquoi n'y a-t-il pas de méthode inverse_transform pour LLE ? Proposer un pseudo code pour effectuer cette tâche
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    14. Implémenter cette transformation.
# </h3>

# %% [markdown]
# <h3 style="background-color: #fad7a0">
#    15. Comparer l'interpolation linéaire de deux éléments du jeu de données, et la reconstruction de l'interpolation linéaire dans l'espace 2D
# </h3>
